# %% [markdown]
# # Title

# %%
# Imports
import cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

# %% [markdown]
# ## Part 1: Object Blending
# Be supported by an image filter

# %%
def ExtractObject(S2, ObjectMask):
    return cv2.bitwise_and(image, mask)

ApplyFilter( ExtractedObject, FilterIndex):
    # Three filters need to be implemented
    # FilterIndex 0 means use no filter
    return

# Maybe make auxiliary function to use only two params for this
ObjectBlender(S1, FilteredExObject, ObjectMask):
    background = cv2.bitwise_and(S1, cv2.bitwise_not(ObjectMask))
    alpha = 1
    beta = 1
    blend = cv2.addWeighted(background, alpha, extracted, beta, 0)
# Out:
#   File "<ipython-input-18-0d6fe11e241e>", line 4
#     ApplyFilter( ExtractedObject, FilterIndex):
#                                                ^
# SyntaxError: invalid syntax

# %%
# Test techniques with dataset on file but later implement with online dataset
# Reading the image
image = cv2.imread('COTSDataset/Part 2 - Multiple Objects/academic_book_no/3_colour.jpeg')
mask = cv2.imread('COTSDataset/Part 2 - Multiple Objects/academic_book_no/masks/ac_3_colour_mask_8_mask.png')


extracted = cv2.bitwise_and(image, mask)
plt.imshow(extracted[:,:,::-1])

# %%
# Somehow add image filter
scene_1 = cv2.imread('COTSDataset/Part 2 - Multiple Objects/academic_book_no/1_colour.jpeg')
background = cv2.bitwise_and(scene_1, cv2.bitwise_not(mask))
alpha = 1
beta = 1
blend = cv2.addWeighted(background, alpha, extracted, beta, 0)
#plt.imshow(image[:,:,::-1])
plt.imshow(blend[:,:,::-1])

# %%
# Perform evaluation using evaluation metrics

# %% [markdown]
# ## Part 2: Image Inpainting

# %%
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

# %%
inpainted = cv2.inpaint(background, mask, 10, cv2.INPAINT_TELEA)
plt.imshow(inpainted[:,:,::-1])

# %%
plt.imshow(background)
